# %%
# %pylab inline

# The following imports are not strictly necessary: they
# are done by default with the above pylab mode command
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.random.normal(size=1000)

fig, ax = plt.subplots()

H = ax.hist(x, bins=50, alpha=0.2, histtype='step')
ax.hist(x, bins=75, alpha=0.5, color='g')

''
# Out:
# ''

# %%
fracs = [74, 12, 6, 10]
colors = ['b', 'g', 'r', 'w']

fig, ax = plt.subplots(figsize=(6, 6))  # make the plot square
pie = ax.pie(fracs, colors=colors, explode=(0.1, 0, 0.05, 0), shadow=True,
             labels=['A', 'B', 'C', 'D'])

# %%
x = np.linspace(0, 10, 30)
dy = 0.25
y = np.random.normal(np.sin(x), dy)

fig, ax = plt.subplots()
plt.errorbar(x, y, dy, fmt='.k')
# Out:
# <Container object of 3 artists>

# %%
x = np.linspace(0, 10, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

fig, ax = plt.subplots()
ax.fill_between(x, y1, y2, where=(y1 < y2), color='red')
ax.fill_between(y1, x, y2, where=(x > y2), color='blue')

# %%
x = np.random.random(50)
y = np.random.random(50)
c = np.random.random(50)  # color of points
s = 500 * np.random.random(50)  # size of points

fig, ax = plt.subplots()
im = ax.scatter(x, y, c=c, s=s, cmap=plt.cm.jet)

# Add a colorbar
fig.colorbar(im, ax=ax)

# set the color limits - not necessary here, but good to know how.
im.set_clim(0.2, 0.8)

# %%
x = np.linspace(0, 10, 50)
y = np.linspace(0, 20, 60)

z = np.cos(y[:, np.newaxis]) * np.sin(x)

fig, ax = plt.subplots()

# filled contours
im = ax.contourf(x, y, z, 100, alpha=0.2)

# contour lines
im2 = ax.contour(x, y, z, alpha=0.3, colors='r')

for spine in ax.spines.values():
    spine.set_color('none')

fig.colorbar(im, ax=ax)

# %%
x, y = np.random.normal(size=(2, 10000))

fig, ax = plt.subplots()
im = ax.hexbin(x, y, gridsize=20)
fig.colorbar(im, ax=ax)

fig, ax = plt.subplots()
H = ax.hist2d(x, y, bins=20)
fig.colorbar(H[3], ax=ax)

# %%
# !git add . 
# !git commit -m 'configu'
